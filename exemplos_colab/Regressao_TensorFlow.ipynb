# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam

# %%
N=1000
X=np.random.random((N,2))*6-3
Y=np.cos(2*X[:,0])+np.cos(3*X[:,1])

# %%
fig=plt.figure(figsize=(12,8))
ax= fig.add_subplot(111,projection='3d')
ax.scatter(X[:,0],X[:,1],Y)
plt.show()

# %%
Xtrain, Xtest, Ytrain, Ytest=train_test_split(X,Y,test_size=0.33)

# %%
modelo = Sequential([Dense(128,input_shape=(2,)),
                     Activation('relu'),
                     Dense(64),
                     Activation('relu'),
                     Dense(1)])

# %%
modelo2=Sequential()
modelo2.add(Dense(128,input_shape=(2,)))
modelo2.add(Activation('relu'))
modelo2.add(Dense(64))
modelo2.add(Activation('relu'))
modelo2.add(Dense(1))

# %%
modelo.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_2 (Dense)             (None, 128)               384
#
#  activation_1 (Activation)   (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  activation_2 (Activation)   (None, 64)                0
#
#  dense_4 (Dense)             (None, 1)                 65
#
# ...
# Total params: 8,705
# Trainable params: 8,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelo.compile(optimizer=Adam(), loss='mse')

# %%
hist= modelo.fit(Xtrain, Ytrain, epochs=100,batch_size=50, validation_data=(Xtest, Ytest))
# Out:
# Epoch 1/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0035 - val_loss: 0.0062
# Epoch 2/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0036 - val_loss: 0.0048
# Epoch 3/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0041 - val_loss: 0.0059
# Epoch 4/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0064
# Epoch 5/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0046 - val_loss: 0.0058
# Epoch 6/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0041 - val_loss: 0.0048
# Epoch 7/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0076
# Epoch 8/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0042 - val_loss: 0.0062
# Epoch 9/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0042
# Epoch 10/100
# ...

# %%
plt.plot(hist.history["loss"])
plt.plot(hist.history["val_loss"])
plt.show()
